# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.multiprocessing as mp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from datetime import datetime
import time

# Set up matplotlib
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# Check available GPUs
num_gpus = torch.cuda.device_count()
print(f"Number of GPUs found: {num_gpus}")

def to_onehot(x, n):
    x_onehot = np.zeros((len(x), n), dtype=np.int64)
    for i in range(len(x)):
        x_onehot[i, x[i]] = 1
    return x_onehot

def corr_finder(hidden_all, test_trials, tr_len, hidden_size):    
    hidden_all = hidden_all.cpu().detach().numpy()
    test0 = np.where(test_trials==0)[0]
    test0_act = np.zeros((tr_len, hidden_size, len(test0)))
    count = 0
    for i in test0:
        test0_act[:,:,count] = hidden_all[i*tr_len: (i+1)*tr_len,:]
        count = count + 1

    test1 = np.where(test_trials==1)[0]
    test1_act = np.zeros((tr_len, hidden_size, len(test1)))
    count = 0
    for i in test1:
        test1_act[:,:,count] = hidden_all[i*tr_len: (i+1)*tr_len,:]
        count = count + 1
    corrplot = np.corrcoef(np.mean(test0_act, axis=2), np.mean(test1_act, axis=2))
    return corrplot

class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, dropout_rate=0.5):
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(hidden_size, output_size, bias=False)

    def forward(self, x):
        lstm_out, _ = self.lstm(x.unsqueeze(0))
        lstm_out = lstm_out.squeeze(0)
        lstm_out = self.dropout(lstm_out)
        out = self.fc(lstm_out)
        return out, lstm_out

def run_simulation(gpu_id, seeds, shared_dict):
    torch.cuda.set_device(gpu_id)
    device = torch.device(f"cuda:{gpu_id}")
    
    trial1x = np.array([1,1,1,1,1,1,2,2,2,2,1,1,1,4,6,1,1,1,5,5,1,1,0])
    trial2x = np.array([1,1,1,1,1,1,3,3,3,3,1,1,1,4,4,1,1,1,5,6,1,1,0])

    num_trials = 100
    num_trials_train = 50
    tr_len = len(trial1x)
    OBS = len(np.unique(np.concatenate((trial1x, trial2x))))
    input_size = OBS
    hidden_size = 1200
    output_size = OBS
    epochs = 3000
    save_each = 10
    dropout_rate = 0.5  # Dropout rate

    loss_all = np.zeros((len(seeds), int(epochs/save_each)))
    corr_curve = np.zeros((len(seeds), int(epochs/save_each), tr_len*2, tr_len*2))
    accuracy_curve_all_test = np.zeros((len(seeds), int(epochs/save_each)))

    for idx, seed in enumerate(seeds):
        print(f'GPU {gpu_id}: Starting simulation {idx+1}/{len(seeds)} with seed {seed}')
        torch.manual_seed(seed)
        np.random.seed(seed)
        
        lstm = LSTM(input_size, hidden_size, output_size, dropout_rate).to(device)
        loss_func = nn.CrossEntropyLoss()
        optimizer = optim.Adam(lstm.parameters(), lr=3e-4)
        
        total_train_time = 0

        for epoch in range(epochs):
            epoch_start_time = time.time()
            
            found_trials = False
            while not found_trials:
                trials = np.random.choice(2, num_trials)
                if np.sum(trials[:num_trials_train]==1)>1 and np.sum(trials[:num_trials_train]==0)>1:
                    found_trials = True
            x = np.zeros(num_trials*tr_len, dtype=np.int64)

            for trial in range(len(trials)):
                if trials[trial] == 0:
                    x[trial*tr_len: (trial+1)*tr_len] = trial1x
                else:
                    x[trial*tr_len: (trial+1)*tr_len] = trial2x

            x = to_onehot(x, OBS)
            
            train_x = torch.tensor(x[0:num_trials_train*tr_len], dtype=torch.float32).to(device)
            test_x = torch.tensor(x[num_trials_train*tr_len:], dtype=torch.float32).to(device)

            optimizer.zero_grad()
            input_x = train_x[:-1]

            prediction, _ = lstm(input_x)

            loss = loss_func(prediction, train_x[1:].argmax(axis=1))

            loss.backward()
            optimizer.step()
            
            epoch_end_time = time.time()
            epoch_duration = epoch_end_time - epoch_start_time
            total_train_time += epoch_duration
            
            if epoch % save_each == 0:
                with torch.no_grad():
                    lstm.eval()  # Set the model to evaluation mode
                    pred_test, hidden_test = lstm(test_x)
                    actual_reward = np.where(test_x[1:].cpu().argmax(axis=1) == 6)
                    predicted_reward = np.where(pred_test.cpu().argmax(axis=1) == 6)
                    accuracy = len(np.intersect1d(actual_reward, predicted_reward)) / len(actual_reward[0])
                    accuracy_curve_all_test[idx, int(epoch/save_each)] = accuracy

                    corr_curve[idx, int(epoch/save_each)] = corr_finder(hidden_test, trials[num_trials_train:], tr_len, hidden_size)

                    loss_all[idx, int(epoch/save_each)] = loss.item()
                
                print(f"GPU {gpu_id}, Sim {idx+1}, Epoch {epoch}/{epochs} - Loss: {loss.item():.4f} - Accuracy: {accuracy:.4f}")
                lstm.train()  # Set the model back to training mode

        print(f"GPU {gpu_id}: Simulation {idx+1} completed. Total training time: {total_train_time:.2f} seconds")

    shared_dict[gpu_id] = {
        'loss_all': loss_all,
        'corr_curve': corr_curve,
        'accuracy_curve_all_test': accuracy_curve_all_test
    }


if __name__ == "__main__":
    total_simulations = 8
    seeds_per_gpu = total_simulations // num_gpus
    remaining_seeds = total_simulations % num_gpus

    all_seeds = np.arange(0, 0 + total_simulations)
    
    manager = mp.Manager()
    shared_dict = manager.dict()

    processes = []
    start_idx = 0
    for i in range(num_gpus):
        end_idx = start_idx + seeds_per_gpu + (1 if i < remaining_seeds else 0)
        gpu_seeds = all_seeds[start_idx:end_idx]
        p = mp.Process(target=run_simulation, args=(i, gpu_seeds, shared_dict))
        p.start()
        processes.append(p)
        start_idx = end_idx

    for p in processes:
        p.join()

    # Combine results from all GPUs
    combined_loss_all = np.concatenate([shared_dict[i]['loss_all'] for i in range(num_gpus)])
    combined_corr_curve = np.concatenate([shared_dict[i]['corr_curve'] for i in range(num_gpus)])
    combined_accuracy_curve = np.concatenate([shared_dict[i]['accuracy_curve_all_test'] for i in range(num_gpus)])

    print("\nAll simulations completed. Saving results...")

    name_add = datetime.now().strftime("%Y-%m-%d-%H-%M")
    np.save(f'./corr_curve_{name_add}', combined_corr_curve)
    np.save(f'./accuracy_curve_all_test_{name_add}', combined_accuracy_curve)
    np.save(f'./loss_all_{name_add}', combined_loss_all)

    print(f"Results saved with timestamp: {name_add}")

    print("\nFinal Statistics:")
    print(f"Average loss: {np.mean(combined_loss_all[:, -1]):.4f}")
    print(f"Average accuracy: {np.mean(combined_accuracy_curve[:, -1]):.4f}")

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(np.mean(combined_loss_all, axis=0))
    plt.title("Average Loss Curve")
    plt.xlabel("Epochs (x10)")
    plt.ylabel("Loss")

    plt.subplot(1, 2, 2)
    plt.plot(np.mean(combined_accuracy_curve, axis=0))
    plt.title("Average Accuracy Curve")
    plt.xlabel("Epochs (x10)")
    plt.ylabel("Accuracy")

    plt.tight_layout()
    plt.show()

    print("Training visualization completed.")
# Out:
# Number of GPUs found: 4
# GPU 1: Starting simulation 1/2 with seed 2
# GPU 2: Starting simulation 1/2 with seed 4
# GPU 3: Starting simulation 1/2 with seed 6
# GPU 0: Starting simulation 1/2 with seed 0
# GPU 1, Sim 1, Epoch 0/3000 - Loss: 1.9443 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 0/3000 - Loss: 1.9470 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 0/3000 - Loss: 1.9458 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 0/3000 - Loss: 1.9480 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 10/3000 - Loss: 1.7416 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 10/3000 - Loss: 2.6830 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 10/3000 - Loss: 2.2974 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 10/3000 - Loss: 2.3609 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 20/3000 - Loss: 1.8264 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 20/3000 - Loss: 1.3737 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 20/3000 - Loss: 1.4952 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 20/3000 - Loss: 1.3613 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 30/3000 - Loss: 1.8270 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 30/3000 - Loss: 1.3609 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 30/3000 - Loss: 1.3703 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 30/3000 - Loss: 1.3586 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 40/3000 - Loss: 1.8145 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 40/3000 - Loss: 1.3567 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 40/3000 - Loss: 1.3506 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 40/3000 - Loss: 1.3563 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 50/3000 - Loss: 1.7963 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 50/3000 - Loss: 1.3551 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 50/3000 - Loss: 1.3590 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 50/3000 - Loss: 1.3515 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 60/3000 - Loss: 1.7729 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 60/3000 - Loss: 1.3480 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 60/3000 - Loss: 1.3486 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 60/3000 - Loss: 1.3502 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 70/3000 - Loss: 1.3460 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 70/3000 - Loss: 1.3488 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 70/3000 - Loss: 1.7410 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 70/3000 - Loss: 1.3450 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 80/3000 - Loss: 1.3422 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 80/3000 - Loss: 1.3394 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 80/3000 - Loss: 1.6944 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 80/3000 - Loss: 1.3364 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 90/3000 - Loss: 1.3323 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 90/3000 - Loss: 1.3384 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 90/3000 - Loss: 1.5989 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 90/3000 - Loss: 1.3275 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 100/3000 - Loss: 1.3160 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 100/3000 - Loss: 1.3256 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 100/3000 - Loss: 1.4203 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 100/3000 - Loss: 1.3183 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 110/3000 - Loss: 1.2278 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 110/3000 - Loss: 1.3229 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 110/3000 - Loss: 1.3648 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 110/3000 - Loss: 1.2463 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 120/3000 - Loss: 1.3043 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 120/3000 - Loss: 1.2056 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 120/3000 - Loss: 1.3474 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 120/3000 - Loss: 1.1017 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 130/3000 - Loss: 1.2806 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 130/3000 - Loss: 1.2902 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 130/3000 - Loss: 1.3475 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 130/3000 - Loss: 0.9180 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 140/3000 - Loss: 1.2030 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 140/3000 - Loss: 1.2462 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 140/3000 - Loss: 1.3463 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 140/3000 - Loss: 1.3085 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 150/3000 - Loss: 1.3215 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 150/3000 - Loss: 1.2565 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 150/3000 - Loss: 1.3393 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 150/3000 - Loss: 1.2877 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 160/3000 - Loss: 1.2978 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 160/3000 - Loss: 1.2673 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 160/3000 - Loss: 1.3408 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 160/3000 - Loss: 1.2820 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 170/3000 - Loss: 1.2937 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 170/3000 - Loss: 1.2442 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 170/3000 - Loss: 1.3355 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 170/3000 - Loss: 1.2709 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 180/3000 - Loss: 1.2830 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 180/3000 - Loss: 1.1169 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 180/3000 - Loss: 1.3374 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 180/3000 - Loss: 1.2618 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 190/3000 - Loss: 1.2662 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 190/3000 - Loss: 1.0013 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 190/3000 - Loss: 1.3323 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 190/3000 - Loss: 1.2380 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 200/3000 - Loss: 1.2562 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 200/3000 - Loss: 1.4057 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 200/3000 - Loss: 1.3284 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 200/3000 - Loss: 1.2121 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 210/3000 - Loss: 1.2239 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 210/3000 - Loss: 1.3291 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 210/3000 - Loss: 1.3220 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 210/3000 - Loss: 1.1619 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 220/3000 - Loss: 1.2014 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 220/3000 - Loss: 1.2735 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 220/3000 - Loss: 1.3234 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 220/3000 - Loss: 1.0254 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 230/3000 - Loss: 1.1011 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 230/3000 - Loss: 1.2462 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 230/3000 - Loss: 1.3153 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 230/3000 - Loss: 0.9170 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 240/3000 - Loss: 0.9966 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 240/3000 - Loss: 1.2097 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 240/3000 - Loss: 1.3134 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 240/3000 - Loss: 0.8801 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 250/3000 - Loss: 0.8456 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 250/3000 - Loss: 1.1514 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 250/3000 - Loss: 1.3067 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 250/3000 - Loss: 0.7107 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 260/3000 - Loss: 1.2509 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 260/3000 - Loss: 0.9852 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 260/3000 - Loss: 1.2933 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 260/3000 - Loss: 0.6103 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 270/3000 - Loss: 1.1219 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 270/3000 - Loss: 0.7925 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 270/3000 - Loss: 1.2831 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 270/3000 - Loss: 0.4989 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 280/3000 - Loss: 1.0708 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 280/3000 - Loss: 1.3666 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 280/3000 - Loss: 1.2659 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 280/3000 - Loss: 0.4190 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 290/3000 - Loss: 0.9118 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 290/3000 - Loss: 0.9497 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 290/3000 - Loss: 1.2398 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 290/3000 - Loss: 0.3766 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 300/3000 - Loss: 0.7824 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 300/3000 - Loss: 1.7188 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 300/3000 - Loss: 1.1490 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 300/3000 - Loss: 0.3802 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 310/3000 - Loss: 0.6851 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 310/3000 - Loss: 1.6343 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 310/3000 - Loss: 1.1944 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 310/3000 - Loss: 0.3267 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 320/3000 - Loss: 0.5907 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 320/3000 - Loss: 1.5437 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 320/3000 - Loss: 1.0470 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 320/3000 - Loss: 0.2626 - Accuracy: 0.4600
# GPU 2, Sim 1, Epoch 330/3000 - Loss: 0.5806 - Accuracy: 0.2400
# GPU 3, Sim 1, Epoch 330/3000 - Loss: 1.4191 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 330/3000 - Loss: 0.2228 - Accuracy: 0.3800
# GPU 1, Sim 1, Epoch 330/3000 - Loss: 0.8953 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 340/3000 - Loss: 0.4298 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 340/3000 - Loss: 1.3572 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 340/3000 - Loss: 0.1704 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 340/3000 - Loss: 0.8166 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 350/3000 - Loss: 0.3341 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 350/3000 - Loss: 1.3244 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 350/3000 - Loss: 0.1523 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 350/3000 - Loss: 0.7416 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 360/3000 - Loss: 2.6749 - Accuracy: 0.1000
# GPU 3, Sim 1, Epoch 360/3000 - Loss: 1.3172 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 360/3000 - Loss: 3.3834 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 360/3000 - Loss: 0.7264 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 370/3000 - Loss: 1.1518 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 370/3000 - Loss: 1.3222 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 370/3000 - Loss: 1.8435 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 370/3000 - Loss: 0.6997 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 380/3000 - Loss: 1.0636 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 380/3000 - Loss: 1.3100 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 380/3000 - Loss: 1.3408 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 380/3000 - Loss: 0.6344 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 390/3000 - Loss: 0.9252 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 390/3000 - Loss: 1.3110 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 390/3000 - Loss: 1.2894 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 390/3000 - Loss: 0.5924 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 400/3000 - Loss: 0.7990 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 400/3000 - Loss: 1.3146 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 400/3000 - Loss: 1.2434 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 400/3000 - Loss: 1.0286 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 410/3000 - Loss: 0.7083 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 410/3000 - Loss: 1.3090 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 410/3000 - Loss: 1.1933 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 410/3000 - Loss: 1.0764 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 420/3000 - Loss: 0.6139 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 420/3000 - Loss: 1.3013 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 420/3000 - Loss: 1.1183 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 420/3000 - Loss: 0.9129 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 430/3000 - Loss: 0.5311 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 430/3000 - Loss: 1.2888 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 430/3000 - Loss: 0.9925 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 440/3000 - Loss: 0.4331 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 430/3000 - Loss: 0.7643 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 440/3000 - Loss: 1.2901 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 440/3000 - Loss: 0.8339 - Accuracy: 0.3600
# GPU 2, Sim 1, Epoch 450/3000 - Loss: 0.3305 - Accuracy: 0.4800
# GPU 1, Sim 1, Epoch 440/3000 - Loss: 0.6981 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 450/3000 - Loss: 1.2854 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 460/3000 - Loss: 1.0519 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 450/3000 - Loss: 0.6912 - Accuracy: 0.2600
# GPU 3, Sim 1, Epoch 460/3000 - Loss: 1.2771 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 450/3000 - Loss: 0.6675 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 470/3000 - Loss: 0.7852 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 460/3000 - Loss: 0.5805 - Accuracy: 0.3200
# GPU 3, Sim 1, Epoch 470/3000 - Loss: 1.2744 - Accuracy: 0.0000
# GPU 1, Sim 1, Epoch 460/3000 - Loss: 0.6254 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 480/3000 - Loss: 0.6644 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 480/3000 - Loss: 1.2473 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 470/3000 - Loss: 0.8202 - Accuracy: 0.0200
# GPU 1, Sim 1, Epoch 470/3000 - Loss: 0.5956 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 490/3000 - Loss: 0.5248 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 490/3000 - Loss: 1.2416 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 480/3000 - Loss: 0.5102 - Accuracy: 0.0200
# GPU 1, Sim 1, Epoch 480/3000 - Loss: 0.5581 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 500/3000 - Loss: 0.4372 - Accuracy: 0.5200
# GPU 3, Sim 1, Epoch 500/3000 - Loss: 1.2185 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 490/3000 - Loss: 0.3772 - Accuracy: 0.4600
# GPU 1, Sim 1, Epoch 490/3000 - Loss: 0.5231 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 510/3000 - Loss: 0.3597 - Accuracy: 0.5400
# GPU 3, Sim 1, Epoch 510/3000 - Loss: 1.1838 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 500/3000 - Loss: 0.2900 - Accuracy: 0.4000
# GPU 1, Sim 1, Epoch 500/3000 - Loss: 0.4904 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 520/3000 - Loss: 0.2971 - Accuracy: 0.5000
# GPU 3, Sim 1, Epoch 520/3000 - Loss: 1.1120 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 510/3000 - Loss: 0.2294 - Accuracy: 0.7800
# GPU 1, Sim 1, Epoch 510/3000 - Loss: 0.4514 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 530/3000 - Loss: 0.2604 - Accuracy: 0.9800
# GPU 3, Sim 1, Epoch 530/3000 - Loss: 0.9951 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 520/3000 - Loss: 0.1869 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 520/3000 - Loss: 0.4296 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 540/3000 - Loss: 0.2306 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 540/3000 - Loss: 0.8232 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 530/3000 - Loss: 0.1594 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 530/3000 - Loss: 0.8358 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 550/3000 - Loss: 0.3938 - Accuracy: 0.0200
# GPU 3, Sim 1, Epoch 550/3000 - Loss: 0.6705 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 540/3000 - Loss: 0.1276 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 540/3000 - Loss: 0.5566 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 560/3000 - Loss: 0.3121 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 560/3000 - Loss: 0.5471 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 550/3000 - Loss: 0.1098 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 550/3000 - Loss: 0.4807 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 570/3000 - Loss: 0.2239 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 570/3000 - Loss: 0.4395 - Accuracy: 0.4800
# GPU 0, Sim 1, Epoch 560/3000 - Loss: 0.1045 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 560/3000 - Loss: 0.4379 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 580/3000 - Loss: 0.1957 - Accuracy: 0.3200
# GPU 3, Sim 1, Epoch 580/3000 - Loss: 0.3919 - Accuracy: 0.5800
# GPU 0, Sim 1, Epoch 570/3000 - Loss: 0.0872 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 570/3000 - Loss: 0.3912 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 590/3000 - Loss: 0.1712 - Accuracy: 0.5000
# GPU 3, Sim 1, Epoch 590/3000 - Loss: 0.6713 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 580/3000 - Loss: 0.0814 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 580/3000 - Loss: 0.3771 - Accuracy: 0.4400
# GPU 2, Sim 1, Epoch 600/3000 - Loss: 0.1498 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 600/3000 - Loss: 0.9689 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 590/3000 - Loss: 0.0742 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 590/3000 - Loss: 0.3369 - Accuracy: 0.5000
# GPU 2, Sim 1, Epoch 610/3000 - Loss: 0.1350 - Accuracy: 0.5400
# GPU 3, Sim 1, Epoch 610/3000 - Loss: 0.7053 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 600/3000 - Loss: 0.0679 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 600/3000 - Loss: 0.3018 - Accuracy: 0.4800
# GPU 2, Sim 1, Epoch 620/3000 - Loss: 0.1289 - Accuracy: 0.6400
# GPU 3, Sim 1, Epoch 620/3000 - Loss: 0.5584 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 610/3000 - Loss: 0.0707 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 610/3000 - Loss: 0.2825 - Accuracy: 0.4200
# GPU 2, Sim 1, Epoch 630/3000 - Loss: 0.1212 - Accuracy: 0.5000
# GPU 3, Sim 1, Epoch 630/3000 - Loss: 0.4346 - Accuracy: 0.0400
# GPU 0, Sim 1, Epoch 620/3000 - Loss: 0.0689 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 620/3000 - Loss: 0.2675 - Accuracy: 0.4600
# GPU 2, Sim 1, Epoch 640/3000 - Loss: 0.1102 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 640/3000 - Loss: 0.3385 - Accuracy: 0.4800
# GPU 0, Sim 1, Epoch 630/3000 - Loss: 0.0651 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 630/3000 - Loss: 0.2433 - Accuracy: 0.5200
# GPU 2, Sim 1, Epoch 650/3000 - Loss: 0.1020 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 650/3000 - Loss: 0.2816 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 640/3000 - Loss: 0.0641 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 640/3000 - Loss: 0.2211 - Accuracy: 0.5400
# GPU 2, Sim 1, Epoch 660/3000 - Loss: 0.0891 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 660/3000 - Loss: 0.2420 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 650/3000 - Loss: 0.0599 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 650/3000 - Loss: 0.2106 - Accuracy: 0.4600
# GPU 2, Sim 1, Epoch 670/3000 - Loss: 0.0887 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 670/3000 - Loss: 0.2124 - Accuracy: 0.9800
# GPU 0, Sim 1, Epoch 660/3000 - Loss: 0.0626 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 660/3000 - Loss: 1.6589 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 680/3000 - Loss: 0.0831 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 680/3000 - Loss: 0.1897 - Accuracy: 0.9800
# GPU 0, Sim 1, Epoch 670/3000 - Loss: 0.0581 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 670/3000 - Loss: 0.9235 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 690/3000 - Loss: 0.0729 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 690/3000 - Loss: 0.1722 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 680/3000 - Loss: 0.0559 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 680/3000 - Loss: 0.7666 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 700/3000 - Loss: 0.0695 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 700/3000 - Loss: 0.1522 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 690/3000 - Loss: 0.0536 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 690/3000 - Loss: 0.7082 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 710/3000 - Loss: 0.0658 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 710/3000 - Loss: 0.1382 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 700/3000 - Loss: 0.0548 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 700/3000 - Loss: 0.5505 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 720/3000 - Loss: 0.0633 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 720/3000 - Loss: 0.1272 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 710/3000 - Loss: 0.0544 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 710/3000 - Loss: 0.4932 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 730/3000 - Loss: 0.0640 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 730/3000 - Loss: 0.1172 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 720/3000 - Loss: 0.0544 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 720/3000 - Loss: 0.4226 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 740/3000 - Loss: 0.0589 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 740/3000 - Loss: 0.1070 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 730/3000 - Loss: 0.0534 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 730/3000 - Loss: 0.3911 - Accuracy: 0.4800
# GPU 2, Sim 1, Epoch 750/3000 - Loss: 0.0571 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 750/3000 - Loss: 0.0937 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 740/3000 - Loss: 0.0488 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 740/3000 - Loss: 0.3507 - Accuracy: 0.4800
# GPU 2, Sim 1, Epoch 760/3000 - Loss: 0.0540 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 760/3000 - Loss: 0.0952 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 750/3000 - Loss: 0.0524 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 750/3000 - Loss: 0.3220 - Accuracy: 0.6000
# GPU 2, Sim 1, Epoch 770/3000 - Loss: 0.0573 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 770/3000 - Loss: 0.0920 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 760/3000 - Loss: 0.0549 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 760/3000 - Loss: 0.2819 - Accuracy: 0.4200
# GPU 2, Sim 1, Epoch 780/3000 - Loss: 0.0517 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 780/3000 - Loss: 0.0886 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 770/3000 - Loss: 0.0494 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 770/3000 - Loss: 0.2652 - Accuracy: 0.5800
# GPU 2, Sim 1, Epoch 790/3000 - Loss: 0.0498 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 790/3000 - Loss: 0.0814 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 780/3000 - Loss: 0.0516 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 800/3000 - Loss: 0.0511 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 780/3000 - Loss: 0.3217 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 800/3000 - Loss: 0.0801 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 790/3000 - Loss: 0.0487 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 810/3000 - Loss: 0.0483 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 790/3000 - Loss: 1.2744 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 810/3000 - Loss: 0.0738 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 800/3000 - Loss: 0.0498 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 820/3000 - Loss: 0.0546 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 800/3000 - Loss: 1.1461 - Accuracy: 0.0000
# GPU 3, Sim 1, Epoch 820/3000 - Loss: 0.0717 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 810/3000 - Loss: 0.0511 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 830/3000 - Loss: 0.0522 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 810/3000 - Loss: 1.0237 - Accuracy: 0.1000
# GPU 3, Sim 1, Epoch 830/3000 - Loss: 0.0706 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 820/3000 - Loss: 0.0482 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 840/3000 - Loss: 0.0470 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 840/3000 - Loss: 0.0707 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 820/3000 - Loss: 0.9335 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 830/3000 - Loss: 0.0452 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 850/3000 - Loss: 0.0463 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 850/3000 - Loss: 0.0635 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 830/3000 - Loss: 0.8615 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 840/3000 - Loss: 0.0471 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 860/3000 - Loss: 0.0526 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 860/3000 - Loss: 0.0663 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 840/3000 - Loss: 0.7342 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 850/3000 - Loss: 0.0466 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 870/3000 - Loss: 0.0473 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 870/3000 - Loss: 0.0707 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 850/3000 - Loss: 0.6220 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 860/3000 - Loss: 0.0451 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 880/3000 - Loss: 0.0511 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 880/3000 - Loss: 0.0610 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 860/3000 - Loss: 0.7633 - Accuracy: 0.0000
# GPU 0, Sim 1, Epoch 870/3000 - Loss: 0.0464 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 890/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 890/3000 - Loss: 0.0600 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 870/3000 - Loss: 0.5699 - Accuracy: 0.4600
# GPU 0, Sim 1, Epoch 880/3000 - Loss: 0.0453 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 900/3000 - Loss: 0.0478 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 900/3000 - Loss: 0.0590 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 880/3000 - Loss: 0.4353 - Accuracy: 0.9800
# GPU 0, Sim 1, Epoch 890/3000 - Loss: 0.0453 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 910/3000 - Loss: 0.0480 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 910/3000 - Loss: 0.0669 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 890/3000 - Loss: 0.3429 - Accuracy: 0.4400
# GPU 0, Sim 1, Epoch 900/3000 - Loss: 0.0458 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 920/3000 - Loss: 0.0405 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 920/3000 - Loss: 0.0573 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 900/3000 - Loss: 0.2737 - Accuracy: 0.6600
# GPU 0, Sim 1, Epoch 910/3000 - Loss: 0.0438 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 930/3000 - Loss: 0.0445 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 930/3000 - Loss: 0.0571 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 910/3000 - Loss: 0.2425 - Accuracy: 0.4800
# GPU 2, Sim 1, Epoch 940/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 920/3000 - Loss: 0.0457 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 940/3000 - Loss: 0.0558 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 920/3000 - Loss: 0.2527 - Accuracy: 0.5000
# GPU 2, Sim 1, Epoch 950/3000 - Loss: 0.0434 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 930/3000 - Loss: 0.0460 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 950/3000 - Loss: 0.0545 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 930/3000 - Loss: 0.2023 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 960/3000 - Loss: 0.0442 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 940/3000 - Loss: 0.0460 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 960/3000 - Loss: 0.0557 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 940/3000 - Loss: 0.1904 - Accuracy: 0.4200
# GPU 2, Sim 1, Epoch 970/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 950/3000 - Loss: 0.0534 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 970/3000 - Loss: 0.0549 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 950/3000 - Loss: 0.1724 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 980/3000 - Loss: 0.0428 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 960/3000 - Loss: 0.0412 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 980/3000 - Loss: 0.0587 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 960/3000 - Loss: 0.1534 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 990/3000 - Loss: 0.0405 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 970/3000 - Loss: 0.0412 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 990/3000 - Loss: 0.0509 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 970/3000 - Loss: 0.1497 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 1000/3000 - Loss: 0.0434 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 980/3000 - Loss: 0.0433 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1000/3000 - Loss: 0.0551 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 980/3000 - Loss: 0.1440 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 1010/3000 - Loss: 0.0436 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1010/3000 - Loss: 0.0494 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 990/3000 - Loss: 0.0432 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 990/3000 - Loss: 0.1291 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 1020/3000 - Loss: 0.0406 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1020/3000 - Loss: 0.0530 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1000/3000 - Loss: 0.0431 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1000/3000 - Loss: 0.1213 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 1030/3000 - Loss: 0.0406 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1030/3000 - Loss: 0.0513 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1010/3000 - Loss: 0.0421 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1010/3000 - Loss: 0.1152 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1040/3000 - Loss: 0.0435 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1040/3000 - Loss: 0.0472 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1020/3000 - Loss: 0.0479 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1020/3000 - Loss: 0.1027 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1050/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1050/3000 - Loss: 0.0527 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1030/3000 - Loss: 0.0413 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1030/3000 - Loss: 0.1029 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1060/3000 - Loss: 0.0414 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1060/3000 - Loss: 0.0548 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1040/3000 - Loss: 0.0396 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1040/3000 - Loss: 0.0868 - Accuracy: 0.9800
# GPU 2, Sim 1, Epoch 1070/3000 - Loss: 0.0426 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1070/3000 - Loss: 0.0521 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1050/3000 - Loss: 0.0480 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1050/3000 - Loss: 0.1105 - Accuracy: 0.7600
# GPU 2, Sim 1, Epoch 1080/3000 - Loss: 0.0428 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1080/3000 - Loss: 0.0534 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1060/3000 - Loss: 0.0408 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1060/3000 - Loss: 2.0979 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 1090/3000 - Loss: 0.0363 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1090/3000 - Loss: 0.0560 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1070/3000 - Loss: 0.0436 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1070/3000 - Loss: 1.0677 - Accuracy: 0.0000
# GPU 2, Sim 1, Epoch 1100/3000 - Loss: 0.0361 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1100/3000 - Loss: 0.0487 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1080/3000 - Loss: 0.0404 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1080/3000 - Loss: 0.8376 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1110/3000 - Loss: 0.0408 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1110/3000 - Loss: 0.0514 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1090/3000 - Loss: 0.0426 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1090/3000 - Loss: 0.6990 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1120/3000 - Loss: 0.0374 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1120/3000 - Loss: 0.0493 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1100/3000 - Loss: 0.0435 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1100/3000 - Loss: 0.5846 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1130/3000 - Loss: 0.0449 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1130/3000 - Loss: 0.0438 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1110/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1110/3000 - Loss: 0.4854 - Accuracy: 0.9600
# GPU 2, Sim 1, Epoch 1140/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1140/3000 - Loss: 0.0489 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1120/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1150/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1120/3000 - Loss: 0.3859 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1150/3000 - Loss: 0.0448 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1130/3000 - Loss: 0.0435 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1160/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1130/3000 - Loss: 0.3205 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1160/3000 - Loss: 0.0464 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1140/3000 - Loss: 0.0419 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1170/3000 - Loss: 0.0395 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1140/3000 - Loss: 0.2541 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1170/3000 - Loss: 0.0440 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1150/3000 - Loss: 0.0394 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1180/3000 - Loss: 0.0369 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1150/3000 - Loss: 0.2068 - Accuracy: 0.9800
# GPU 3, Sim 1, Epoch 1180/3000 - Loss: 0.0449 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1160/3000 - Loss: 0.0365 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1190/3000 - Loss: 0.0410 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1160/3000 - Loss: 0.1784 - Accuracy: 0.9800
# GPU 3, Sim 1, Epoch 1190/3000 - Loss: 0.0485 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1170/3000 - Loss: 0.0416 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1200/3000 - Loss: 0.0421 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1170/3000 - Loss: 0.1562 - Accuracy: 0.9800
# GPU 3, Sim 1, Epoch 1200/3000 - Loss: 0.0513 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1180/3000 - Loss: 0.0400 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1210/3000 - Loss: 0.0383 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1180/3000 - Loss: 0.1304 - Accuracy: 0.9800
# GPU 3, Sim 1, Epoch 1210/3000 - Loss: 0.0460 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1190/3000 - Loss: 0.0401 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1220/3000 - Loss: 0.0396 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1220/3000 - Loss: 0.0449 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1190/3000 - Loss: 0.1257 - Accuracy: 0.9800
# GPU 0, Sim 1, Epoch 1200/3000 - Loss: 0.0378 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1230/3000 - Loss: 0.0442 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1230/3000 - Loss: 0.0457 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1200/3000 - Loss: 0.1126 - Accuracy: 0.9800
# GPU 0, Sim 1, Epoch 1210/3000 - Loss: 0.0429 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1240/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1240/3000 - Loss: 0.0483 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1210/3000 - Loss: 0.1013 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1220/3000 - Loss: 0.0459 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1250/3000 - Loss: 0.0438 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1250/3000 - Loss: 0.0428 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1220/3000 - Loss: 0.0945 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1230/3000 - Loss: 0.0422 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1260/3000 - Loss: 0.0563 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1260/3000 - Loss: 0.0473 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1230/3000 - Loss: 0.0905 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1240/3000 - Loss: 0.0407 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1270/3000 - Loss: 0.0400 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1270/3000 - Loss: 0.0458 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1240/3000 - Loss: 0.0830 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1250/3000 - Loss: 0.0407 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1280/3000 - Loss: 0.0346 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1280/3000 - Loss: 0.0477 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1250/3000 - Loss: 0.0839 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1260/3000 - Loss: 0.0391 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1290/3000 - Loss: 0.0372 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1290/3000 - Loss: 0.0470 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1260/3000 - Loss: 0.0793 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1270/3000 - Loss: 0.0363 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1300/3000 - Loss: 0.0404 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1300/3000 - Loss: 0.0438 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1270/3000 - Loss: 0.0759 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1280/3000 - Loss: 0.0381 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1310/3000 - Loss: 0.0386 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1310/3000 - Loss: 0.0443 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1280/3000 - Loss: 0.0674 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1290/3000 - Loss: 0.0381 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1320/3000 - Loss: 0.0370 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1320/3000 - Loss: 0.0461 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1290/3000 - Loss: 0.0677 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1300/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1330/3000 - Loss: 0.0391 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1330/3000 - Loss: 0.0422 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1300/3000 - Loss: 0.0711 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1310/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1340/3000 - Loss: 0.0398 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1340/3000 - Loss: 0.0433 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1310/3000 - Loss: 0.0626 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1320/3000 - Loss: 0.0371 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1350/3000 - Loss: 0.0370 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1350/3000 - Loss: 0.0449 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1320/3000 - Loss: 0.0680 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1330/3000 - Loss: 0.0367 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1360/3000 - Loss: 0.0388 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1360/3000 - Loss: 0.0420 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1330/3000 - Loss: 0.0663 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1370/3000 - Loss: 0.0369 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1340/3000 - Loss: 0.0393 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1370/3000 - Loss: 0.0473 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1340/3000 - Loss: 0.0594 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1380/3000 - Loss: 0.0391 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1350/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1380/3000 - Loss: 0.0432 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1350/3000 - Loss: 0.0622 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1390/3000 - Loss: 0.0364 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1360/3000 - Loss: 0.0388 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1390/3000 - Loss: 0.0424 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1360/3000 - Loss: 0.0603 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1400/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1370/3000 - Loss: 0.0351 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1400/3000 - Loss: 0.0416 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1370/3000 - Loss: 0.0662 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1410/3000 - Loss: 0.0373 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1380/3000 - Loss: 0.0405 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1410/3000 - Loss: 0.0437 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1380/3000 - Loss: 0.0555 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1420/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1390/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1420/3000 - Loss: 0.0404 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1390/3000 - Loss: 0.0577 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1430/3000 - Loss: 0.0346 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1400/3000 - Loss: 0.0373 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1430/3000 - Loss: 0.0438 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1400/3000 - Loss: 0.0508 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1440/3000 - Loss: 0.0352 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1410/3000 - Loss: 0.0406 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1440/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1410/3000 - Loss: 0.0602 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1450/3000 - Loss: 0.0354 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1420/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1450/3000 - Loss: 0.0420 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1420/3000 - Loss: 0.0598 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1460/3000 - Loss: 0.0360 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1430/3000 - Loss: 0.0370 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1460/3000 - Loss: 0.0435 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1430/3000 - Loss: 0.0563 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1470/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1440/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1470/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1480/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1440/3000 - Loss: 0.0622 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1480/3000 - Loss: 0.0400 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1450/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1490/3000 - Loss: 0.0355 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1450/3000 - Loss: 0.0594 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1490/3000 - Loss: 0.0415 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1460/3000 - Loss: 0.0393 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1500/3000 - Loss: 0.0350 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1460/3000 - Loss: 0.0524 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1500/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1470/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1510/3000 - Loss: 0.0402 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1470/3000 - Loss: 0.0562 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1510/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1480/3000 - Loss: 0.0354 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1520/3000 - Loss: 0.0366 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1480/3000 - Loss: 0.0500 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1520/3000 - Loss: 0.0419 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1490/3000 - Loss: 0.0363 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1530/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1490/3000 - Loss: 0.0606 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1530/3000 - Loss: 0.0414 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1500/3000 - Loss: 0.0382 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1540/3000 - Loss: 0.0352 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1500/3000 - Loss: 0.0553 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1540/3000 - Loss: 0.0414 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1510/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1550/3000 - Loss: 0.0374 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1510/3000 - Loss: 0.0527 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1550/3000 - Loss: 0.0399 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1520/3000 - Loss: 0.0340 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1560/3000 - Loss: 0.0374 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1520/3000 - Loss: 0.0528 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1560/3000 - Loss: 0.0376 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1530/3000 - Loss: 0.0382 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1570/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1530/3000 - Loss: 0.0485 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1570/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1540/3000 - Loss: 0.0363 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1580/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1580/3000 - Loss: 0.0410 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1540/3000 - Loss: 0.0503 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1550/3000 - Loss: 0.0361 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1590/3000 - Loss: 0.0383 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1590/3000 - Loss: 0.0404 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1550/3000 - Loss: 0.0528 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1560/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1600/3000 - Loss: 0.0324 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1600/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1560/3000 - Loss: 0.0541 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1570/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1610/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1610/3000 - Loss: 0.0413 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1570/3000 - Loss: 0.0538 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1580/3000 - Loss: 0.0367 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1620/3000 - Loss: 0.0380 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1620/3000 - Loss: 0.0397 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1580/3000 - Loss: 0.0529 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1590/3000 - Loss: 0.0399 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1630/3000 - Loss: 0.0367 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1630/3000 - Loss: 0.0380 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1590/3000 - Loss: 0.0533 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1600/3000 - Loss: 0.0378 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1640/3000 - Loss: 0.0360 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1640/3000 - Loss: 0.0388 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1600/3000 - Loss: 0.0458 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1610/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1650/3000 - Loss: 0.0366 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1650/3000 - Loss: 0.0408 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1610/3000 - Loss: 0.0510 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1620/3000 - Loss: 0.0374 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1660/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1660/3000 - Loss: 0.0409 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1620/3000 - Loss: 0.0508 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1630/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1670/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1670/3000 - Loss: 0.0423 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1630/3000 - Loss: 0.0459 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1640/3000 - Loss: 0.0364 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1680/3000 - Loss: 0.0365 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1680/3000 - Loss: 0.0380 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1640/3000 - Loss: 0.0510 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1650/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1690/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1690/3000 - Loss: 0.0407 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1650/3000 - Loss: 0.0486 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1660/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1700/3000 - Loss: 0.0346 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1700/3000 - Loss: 0.0375 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1660/3000 - Loss: 0.0631 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1670/3000 - Loss: 0.0365 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1710/3000 - Loss: 0.0361 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1710/3000 - Loss: 0.0392 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1670/3000 - Loss: 0.0445 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1680/3000 - Loss: 0.0345 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1720/3000 - Loss: 0.0390 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1720/3000 - Loss: 0.0398 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1680/3000 - Loss: 0.0508 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1690/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1730/3000 - Loss: 0.0355 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1730/3000 - Loss: 0.0386 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1690/3000 - Loss: 0.0532 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1700/3000 - Loss: 0.0359 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1740/3000 - Loss: 0.0389 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1740/3000 - Loss: 0.0401 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1700/3000 - Loss: 0.0483 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1710/3000 - Loss: 0.0357 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1750/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1750/3000 - Loss: 0.0375 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1710/3000 - Loss: 0.0526 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1760/3000 - Loss: 0.0351 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1720/3000 - Loss: 0.0364 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1760/3000 - Loss: 0.0393 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1720/3000 - Loss: 0.0453 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1770/3000 - Loss: 0.0305 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1730/3000 - Loss: 0.0354 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1770/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1730/3000 - Loss: 0.0504 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1780/3000 - Loss: 0.0352 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1740/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1780/3000 - Loss: 0.0368 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1740/3000 - Loss: 0.0531 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1790/3000 - Loss: 0.0361 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1750/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1790/3000 - Loss: 0.0384 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1750/3000 - Loss: 0.0453 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1800/3000 - Loss: 0.0311 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1760/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1800/3000 - Loss: 0.0415 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1760/3000 - Loss: 0.0502 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1810/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1770/3000 - Loss: 0.0344 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1810/3000 - Loss: 0.0445 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1770/3000 - Loss: 0.0425 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1820/3000 - Loss: 0.0354 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1780/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1820/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1830/3000 - Loss: 0.0334 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1780/3000 - Loss: 0.0444 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1790/3000 - Loss: 0.0376 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1830/3000 - Loss: 0.0387 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1840/3000 - Loss: 0.0364 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1790/3000 - Loss: 0.0505 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1800/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1840/3000 - Loss: 0.0389 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1850/3000 - Loss: 0.0379 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1800/3000 - Loss: 0.0486 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1810/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1850/3000 - Loss: 0.0403 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1860/3000 - Loss: 0.0357 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1810/3000 - Loss: 0.0482 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1820/3000 - Loss: 0.0376 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1860/3000 - Loss: 0.0379 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1870/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1820/3000 - Loss: 0.0448 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1830/3000 - Loss: 0.0377 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1870/3000 - Loss: 0.0378 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1880/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1830/3000 - Loss: 0.0469 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1840/3000 - Loss: 0.0367 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1880/3000 - Loss: 0.0372 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1890/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1840/3000 - Loss: 0.0473 - Accuracy: 1.0000
# GPU 0, Sim 1, Epoch 1850/3000 - Loss: 0.0366 - Accuracy: 1.0000
# GPU 3, Sim 1, Epoch 1890/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 2, Sim 1, Epoch 1900/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 1, Sim 1, Epoch 1850/3000 - Loss: 0.0420 - Accuracy: 1.0000
# ...
# GPU 1, Sim 2, Epoch 2310/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2340/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2470/3000 - Loss: 0.0448 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2460/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2320/3000 - Loss: 0.0344 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2350/3000 - Loss: 0.0350 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2480/3000 - Loss: 0.0473 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2470/3000 - Loss: 0.0344 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2330/3000 - Loss: 0.0356 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2360/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2490/3000 - Loss: 0.0500 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2480/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2340/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2370/3000 - Loss: 0.0356 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2500/3000 - Loss: 0.0460 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2490/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2350/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2380/3000 - Loss: 0.0308 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2510/3000 - Loss: 0.0470 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2500/3000 - Loss: 0.0304 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2360/3000 - Loss: 0.0324 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2390/3000 - Loss: 0.0359 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2520/3000 - Loss: 0.0423 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2510/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2370/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2400/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2530/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2520/3000 - Loss: 0.0321 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2380/3000 - Loss: 0.0332 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2410/3000 - Loss: 0.0324 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2540/3000 - Loss: 0.0452 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2530/3000 - Loss: 0.0329 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2390/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2420/3000 - Loss: 0.0318 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2550/3000 - Loss: 0.0481 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2540/3000 - Loss: 0.0328 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2400/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2430/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2560/3000 - Loss: 0.0464 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2550/3000 - Loss: 0.0328 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2410/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2440/3000 - Loss: 0.0351 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2570/3000 - Loss: 0.0414 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2560/3000 - Loss: 0.0322 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2580/3000 - Loss: 0.0452 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2450/3000 - Loss: 0.0340 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2420/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2570/3000 - Loss: 0.0310 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2590/3000 - Loss: 0.0457 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2460/3000 - Loss: 0.0345 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2430/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2580/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2600/3000 - Loss: 0.0467 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2470/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2440/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2590/3000 - Loss: 0.0316 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2610/3000 - Loss: 0.0459 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2480/3000 - Loss: 0.0337 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2450/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2600/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2620/3000 - Loss: 0.0425 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2490/3000 - Loss: 0.0314 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2460/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2610/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2630/3000 - Loss: 0.0446 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2500/3000 - Loss: 0.0352 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2470/3000 - Loss: 0.0313 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2620/3000 - Loss: 0.0323 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2640/3000 - Loss: 0.0444 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2510/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2480/3000 - Loss: 0.0344 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2630/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2650/3000 - Loss: 0.0488 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2520/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2490/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2640/3000 - Loss: 0.0326 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2660/3000 - Loss: 0.0443 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2530/3000 - Loss: 0.0345 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2500/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2650/3000 - Loss: 0.0322 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2670/3000 - Loss: 0.0451 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2540/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2510/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2660/3000 - Loss: 0.0334 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2680/3000 - Loss: 0.0453 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2550/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2520/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2670/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2690/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2560/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2530/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2680/3000 - Loss: 0.0315 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2700/3000 - Loss: 0.0426 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2570/3000 - Loss: 0.0358 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2540/3000 - Loss: 0.0340 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2690/3000 - Loss: 0.0316 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2710/3000 - Loss: 0.0470 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2580/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2550/3000 - Loss: 0.0326 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2700/3000 - Loss: 0.0305 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2720/3000 - Loss: 0.0420 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2590/3000 - Loss: 0.0364 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2560/3000 - Loss: 0.0326 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2710/3000 - Loss: 0.0304 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2730/3000 - Loss: 0.0464 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2600/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2570/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2720/3000 - Loss: 0.0305 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2740/3000 - Loss: 0.0441 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2610/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2580/3000 - Loss: 0.0328 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2730/3000 - Loss: 0.0319 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2750/3000 - Loss: 0.0439 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2620/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2590/3000 - Loss: 0.0363 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2740/3000 - Loss: 0.0305 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2760/3000 - Loss: 0.0442 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2630/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2600/3000 - Loss: 0.0353 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2750/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2770/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2640/3000 - Loss: 0.0339 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2610/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2760/3000 - Loss: 0.0326 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2780/3000 - Loss: 0.0461 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2650/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2620/3000 - Loss: 0.0322 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2770/3000 - Loss: 0.0311 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2790/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2660/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2630/3000 - Loss: 0.0362 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2780/3000 - Loss: 0.0323 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2800/3000 - Loss: 0.0414 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2670/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2640/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2790/3000 - Loss: 0.0316 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2810/3000 - Loss: 0.0421 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2680/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2650/3000 - Loss: 0.0332 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2800/3000 - Loss: 0.0323 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2820/3000 - Loss: 0.0465 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2690/3000 - Loss: 0.0339 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2660/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2810/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2830/3000 - Loss: 0.0418 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2700/3000 - Loss: 0.0322 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2820/3000 - Loss: 0.0315 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2670/3000 - Loss: 0.0345 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2840/3000 - Loss: 0.0448 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2710/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2830/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2680/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2850/3000 - Loss: 0.0421 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2720/3000 - Loss: 0.0355 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2840/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2690/3000 - Loss: 0.0319 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2860/3000 - Loss: 0.0444 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2730/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2850/3000 - Loss: 0.0326 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2700/3000 - Loss: 0.0376 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2870/3000 - Loss: 0.0437 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2740/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2860/3000 - Loss: 0.0307 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2710/3000 - Loss: 0.0340 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2880/3000 - Loss: 0.0451 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2750/3000 - Loss: 0.0352 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2870/3000 - Loss: 0.0328 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2720/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2890/3000 - Loss: 0.0442 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2760/3000 - Loss: 0.0342 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2880/3000 - Loss: 0.0314 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2730/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2900/3000 - Loss: 0.0447 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2890/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2770/3000 - Loss: 0.0332 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2740/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2910/3000 - Loss: 0.0427 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2900/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2780/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2920/3000 - Loss: 0.0406 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2750/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2910/3000 - Loss: 0.0329 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2790/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2930/3000 - Loss: 0.0442 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2760/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2920/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2800/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2940/3000 - Loss: 0.0411 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2770/3000 - Loss: 0.0303 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2930/3000 - Loss: 0.0322 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2810/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2950/3000 - Loss: 0.0417 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2780/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2940/3000 - Loss: 0.0316 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2820/3000 - Loss: 0.0318 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2960/3000 - Loss: 0.0425 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2790/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2950/3000 - Loss: 0.0316 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2830/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2970/3000 - Loss: 0.0431 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2800/3000 - Loss: 0.0331 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2960/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2840/3000 - Loss: 0.0319 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2980/3000 - Loss: 0.0455 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2810/3000 - Loss: 0.0347 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2970/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2850/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 2, Sim 2, Epoch 2990/3000 - Loss: 0.0466 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2820/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2980/3000 - Loss: 0.0332 - Accuracy: 1.0000
# GPU 2: Simulation 2 completed. Total training time: 140.45 seconds
# GPU 0, Sim 2, Epoch 2860/3000 - Loss: 0.0334 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2830/3000 - Loss: 0.0318 - Accuracy: 1.0000
# GPU 3, Sim 2, Epoch 2990/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2870/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2840/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 3: Simulation 2 completed. Total training time: 140.30 seconds
# GPU 0, Sim 2, Epoch 2880/3000 - Loss: 0.0343 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2850/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2890/3000 - Loss: 0.0320 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2860/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2900/3000 - Loss: 0.0321 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2870/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2910/3000 - Loss: 0.0349 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2880/3000 - Loss: 0.0357 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2920/3000 - Loss: 0.0325 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2890/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2930/3000 - Loss: 0.0333 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2900/3000 - Loss: 0.0306 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2940/3000 - Loss: 0.0324 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2910/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2950/3000 - Loss: 0.0336 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2920/3000 - Loss: 0.0338 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2960/3000 - Loss: 0.0339 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2930/3000 - Loss: 0.0345 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2970/3000 - Loss: 0.0335 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2940/3000 - Loss: 0.0344 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2980/3000 - Loss: 0.0330 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2950/3000 - Loss: 0.0361 - Accuracy: 1.0000
# GPU 0, Sim 2, Epoch 2990/3000 - Loss: 0.0341 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2960/3000 - Loss: 0.0327 - Accuracy: 1.0000
# GPU 0: Simulation 2 completed. Total training time: 142.95 seconds
# GPU 1, Sim 2, Epoch 2970/3000 - Loss: 0.0367 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2980/3000 - Loss: 0.0348 - Accuracy: 1.0000
# GPU 1, Sim 2, Epoch 2990/3000 - Loss: 0.0332 - Accuracy: 1.0000
# GPU 1: Simulation 2 completed. Total training time: 144.15 seconds
#
# All simulations completed. Saving results...
# Results saved with timestamp: 2024-09-05-16-50
#
# Final Statistics:
# Average loss: 0.0363
# Average accuracy: 1.0000
# Training visualization completed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from datetime import datetime

# Set up matplotlib
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# Constants
tr_len = 23
loss_thresh = 10.04  # Adjust this if needed

# Load data
try:
    # Assuming name_add is defined and contains the timestamp
    file_chosen = name_add
    print(f"Loading data from files with timestamp: {file_chosen}")
    
    corr_curve = np.load(f'corr_curve_{file_chosen}.npy')
    accuracy_curve_all_test = np.load(f'accuracy_curve_all_test_{file_chosen}.npy')
    loss_all = np.load(f'loss_all_{file_chosen}.npy')
    
    print("Data loaded successfully.")
except NameError:
    print("name_add is not defined. Please provide the timestamp for your data files.")
    # You can uncomment and modify the following line to manually set the timestamp
    # file_chosen = "YYYY-MM-DD-HH-MM"  # Replace with your actual timestamp
    raise
except FileNotFoundError:
    print(f"Data files with timestamp {file_chosen} not found. Please check the file names and path.")
    raise

# Plot mean correlation matrix
plt.figure(figsize=(10, 8))
sb.heatmap(np.mean(corr_curve[:,-1,0:tr_len,tr_len:2*tr_len][loss_all[:,-1]<loss_thresh], axis=0), 
           vmin=-1, vmax=1, cmap='icefire')
for plot_line in [6,10,13,15,18,20]:
    plt.axvline(plot_line, linestyle='--', color='gray')
    plt.axhline(plot_line, linestyle='--', color='gray')
    plt.axvline(plot_line+23, linestyle='--', color='gray')
    plt.axhline(plot_line+23, linestyle='--', color='gray')
plt.title('LSTM average correlation')
plt.show()

# Plot individual correlation matrices
n_plots = min(9, np.sum(loss_all[:,-1] < loss_thresh))
n_rows = int(np.ceil(n_plots / 3))
n_cols = min(n_plots, 3)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 5*n_rows))
axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]

for i in range(n_plots):
    sb.heatmap(corr_curve[:,-1,0:tr_len,tr_len:2*tr_len][loss_all[:,-1]<loss_thresh][i,:,:], 
               vmin=-1, vmax=1, cmap='icefire', ax=axes[i])
    for plot_line in [6,10,13,15,18,20]:
        axes[i].axvline(plot_line, linestyle='--', color='gray')
        axes[i].axhline(plot_line, linestyle='--', color='gray')
        axes[i].axvline(plot_line+23, linestyle='--', color='gray')
        axes[i].axhline(plot_line+23, linestyle='--', color='gray')
    axes[i].set_title(f'LSTM Run {i+1}\nLoss: {loss_all[loss_all[:,-1]<loss_thresh][i,-1]:.4f}')

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# Define regions for correlation analysis
regions = [[0, 6], [10, 13], [15, 18], [20, 23]]
other_regions = np.array([10, 13, 14, 15, 18, 19, 20, 23])

# Create correlation matrices
correlation_matrix_1 = np.zeros((tr_len, tr_len))
for i, region_i in enumerate(regions):
    for j, region_j in enumerate(regions):
        if i != j:
            correlation_matrix_1[region_i[0]:region_i[1], region_j[0]:region_j[1]] = 1

correlation_matrix_2 = np.zeros((tr_len, tr_len))
correlation_matrix_2[other_regions[3]:other_regions[5], other_regions[3]:other_regions[5]] = np.eye(other_regions[5] - other_regions[3])

correlation_matrix_3 = np.zeros((tr_len, tr_len))
correlation_matrix_3[other_regions[0]:other_regions[2], other_regions[0]:other_regions[2]] = np.eye(other_regions[2] - other_regions[0])

correlation_matrices = [correlation_matrix_1, correlation_matrix_2, correlation_matrix_3]
correlation_names = ['Off-diagonal', 'Pre-R2', 'Pre-R1']

# Plot correlation matrices
for i, matrix in enumerate(correlation_matrices):
    plt.figure(figsize=(8, 6))
    sb.heatmap(matrix)
    plt.title(f'Correlation Matrix {i+1}: {correlation_names[i]}')
    plt.show()

print("Correlation matrices plotted.")
print("The first plot shows the average correlation matrix across all good LSTM runs.")
print("The following plots show individual correlation matrices for up to 9 good LSTM runs.")
print("The final three plots show the regions of interest for correlation analysis:")
print("Matrix 1: Off-diagonal regions")
print("Matrix 2: Pre-R2 region")
print("Matrix 3: Pre-R1 region")
# Out:
# Loading data from files with timestamp: 2024-09-05-16-50
# Data loaded successfully.
# Correlation matrices plotted.
# The first plot shows the average correlation matrix across all good LSTM runs.
# The following plots show individual correlation matrices for up to 9 good LSTM runs.
# The final three plots show the regions of interest for correlation analysis:
# Matrix 1: Off-diagonal regions
# Matrix 2: Pre-R2 region
# Matrix 3: Pre-R1 region

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from datetime import datetime
import math

matplotlib.rcParams['pdf.fonttype'] = 42

print("Analysis of GPU LSTM Model Results with Dropout")
print("="*40)

# Constants
tr_len = 23
loss_thresh = 10  # setting a high threshold to include all runs
decorr_thresh = 10 # Threshold for decorrelation analysis

# Load data (update with your LSTM results timestamp)
file_chosen = name_add  # Update this to your actual LSTM results filename
print(f"Loading LSTM data from files with timestamp: {file_chosen}")

corr_curve = np.load(f'corr_curve_{file_chosen}.npy')
accuracy_curve_all_test = np.load(f'accuracy_curve_all_test_{file_chosen}.npy')
loss_all = np.load(f'loss_all_{file_chosen}.npy')

print(f"Data loaded successfully.")
print(f"Total number of simulations: {corr_curve.shape[0]}")
print(f"Number of epochs: {corr_curve.shape[1]}")
print(f"Correlation matrix size: {corr_curve.shape[2]}x{corr_curve.shape[3]}")
print("="*40)

# Basic Statistics
print("Basic Statistics:")
print(f"Final mean loss: {np.mean(loss_all[:,-1]):.4f}")
print(f"Final mean accuracy: {np.mean(accuracy_curve_all_test[:,-1]):.4f}")

# Number of runs with good convergence
good_runs = (loss_all[:,-1] < loss_thresh).sum()
good_run_indices = np.where(loss_all[:,-1] < loss_thresh)[0]
print(f"Number of runs with good convergence (loss < {loss_thresh}): {good_runs}")
print(f"Percentage of good runs: {good_runs/loss_all.shape[0]*100:.2f}%")
print("="*40)

# Plot average accuracy curve for good runs
plt.figure(figsize=(3, 3), dpi=500)
A = accuracy_curve_all_test[good_run_indices] * 100
combined_mean = np.mean(A, axis=0)
combined_sem = np.std(A, axis=0) / np.sqrt(A.shape[0])
x = np.arange(A.shape[1])
plt.plot(x, combined_mean, '-o', label='Mean')
plt.fill_between(x, combined_mean - combined_sem, combined_mean + combined_sem, alpha=0.3)
plt.xlabel('Epoch')
plt.ylabel('Prediction accuracy (%)')
plt.title('Prediction accuracy for good runs')
plt.tight_layout()
plt.savefig(f'./lstm_avg_accuracy_{file_chosen}.pdf', format='pdf', dpi=600)
plt.show()

print("Average accuracy curve plotted for good runs.")
print(f"Final average accuracy for good runs: {np.mean(A[:, -1]):.4f}%")
print("="*40)

# Calculate and print mean final correlation for each run
last_frames = corr_curve[:, -1, 0:tr_len, tr_len:2*tr_len]
mean_last_frame = np.mean(last_frames, axis=0)
overall_mean = np.mean(last_frames)
individual_means = np.mean(last_frames, axis=(1,2))
sem = np.std(individual_means) / np.sqrt(len(individual_means))

print(f"Overall mean of the last frame covariance matrix: {overall_mean:.4f}")
print(f"SEM: {sem:.4f}")
print("Individual means for each run:")
print(individual_means)
print("="*40)

# Plot correlation matrices for selected epochs
mean_corr_curve = np.mean(corr_curve[:, :, 0:tr_len, tr_len:2*tr_len], axis=0)
num_epochs = mean_corr_curve.shape[0]
epochs_to_plot = [0, num_epochs // 4, num_epochs // 2, 3 * num_epochs // 4, num_epochs - 1]

fig, axs = plt.subplots(1, 5, figsize=(20, 4), dpi=300)
for i, epoch in enumerate(epochs_to_plot):
    sns.heatmap(mean_corr_curve[epoch], cmap='icefire', vmin=-1, vmax=1, ax=axs[i], 
                cbar=False, xticklabels=False, yticklabels=False, linewidths=0)
    axs[i].set_aspect('equal')
    axs[i].set_title(f'Epoch {(epoch + 1) * 10}')
    for lines in [6, 10, 13, 15, 18, 20]:  
        axs[i].axvline(lines, linestyle=(0, (2, 5)), color='white', linewidth=1.5)
        axs[i].axhline(lines, linestyle=(0, (2, 5)), color='white', linewidth=1.5)
    for (low, high) in [(6, 10), (13, 15), (18, 20)]:
        axs[i].plot([low, high, high, low, low], [low, low, high, high, low], color='white', linewidth=3)  
plt.tight_layout()
today = datetime.now().strftime('%Y_%m_%d')
plt.savefig(f'LSTM_corr_plot_{today}.pdf', format='pdf', dpi=300)
plt.show()

print("Correlation matrices plotted for selected epochs.")
print("="*40)

# Last time step mean correlation
corr_avg_last_session = np.mean(corr_curve[:,-1,0:tr_len,tr_len:2*tr_len][loss_all[:,-1]<loss_thresh], axis=(1,2))
print("Last time step mean correlation statistics:")
print(f"Mean: {np.mean(corr_avg_last_session):.4f}")
print(f"Median: {np.median(corr_avg_last_session):.4f}")
print(f"Min: {np.min(corr_avg_last_session):.4f}")
print(f"Max: {np.max(corr_avg_last_session):.4f}")
print("="*40)

# Plot mean correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(np.mean(corr_curve[:,-1,0:tr_len,tr_len:2*tr_len][loss_all[:,-1]<loss_thresh], axis=0), 
           vmin=-1, vmax=1, cmap='icefire')
for plot_line in [6,10,13,15,18,20]:
    plt.axvline(plot_line, linestyle='--', color='gray')
    plt.axhline(plot_line, linestyle='--', color='gray')
plt.title('LSTM average correlation')
plt.savefig(f'LSTM_mean_correlation_{today}.pdf', format='pdf', dpi=300)
plt.show()

print("Mean correlation matrix plotted.")
print("="*40)

# Define regions for correlation analysis
regions = [[0, 6], [10, 13], [15, 18], [20, 23]]
other_regions = np.array([10, 13, 14, 15, 18, 19, 20, 23])

# Create correlation matrices
correlation_matrix_1 = np.zeros((tr_len, tr_len))
for i, region_i in enumerate(regions):
    for j, region_j in enumerate(regions):
        if i != j:
            correlation_matrix_1[region_i[0]:region_i[1], region_j[0]:region_j[1]] = 1

correlation_matrix_2 = np.zeros((tr_len, tr_len))
correlation_matrix_2[other_regions[3]:other_regions[5], other_regions[3]:other_regions[5]] = np.eye(other_regions[5] - other_regions[3])

correlation_matrix_3 = np.zeros((tr_len, tr_len))
correlation_matrix_3[other_regions[0]:other_regions[2], other_regions[0]:other_regions[2]] = np.eye(other_regions[2] - other_regions[0])

correlation_matrices = [correlation_matrix_1, correlation_matrix_2, correlation_matrix_3]
correlation_names = ['Off-diagonal', 'Pre-R2', 'Pre-R1']

# Analyze decorrelation
all_masks_matrix = np.full((3, len(good_run_indices), corr_curve.shape[1]), np.nan)

corr_curve_lim = corr_curve[loss_all[:,-1] < loss_thresh]

# Calculate mean values for all regions
for i, session_n in enumerate(range(len(good_run_indices))):
    corr_position_day = corr_curve_lim[session_n][:,0:tr_len, tr_len:2*tr_len]
    for j, mask in enumerate(correlation_matrices):
        mask_array = np.zeros_like(corr_position_day, dtype=bool)
        mask_array += mask.astype(bool)
        masked_a_array = np.ma.masked_array(corr_position_day, mask=~mask_array)
        mean_values_array = masked_a_array.mean(axis=(1, 2))
        all_masks_matrix[j, i, 0:len(mean_values_array)] = mean_values_array

# Additional filtering based on decorrelation threshold
final_means = all_masks_matrix[:, :, -1]
good_decorr_runs = np.all(final_means < decorr_thresh, axis=0)
filtered_indices = good_run_indices[good_decorr_runs]

print(f"Number of LSTM runs passing both loss and decorrelation thresholds: {np.sum(good_decorr_runs)}")
print(f"Percentage of good LSTM runs passing decorrelation threshold: {np.sum(good_decorr_runs)/len(good_run_indices)*100:.2f}%")
print("="*40)

# Plot decorrelation analysis for filtered runs
n_iter = 10
subplots_per_fig = 20
num_figures = math.ceil(np.sum(good_decorr_runs) / subplots_per_fig)

for fig_num in range(num_figures):
    start_idx = fig_num * subplots_per_fig
    end_idx = min((fig_num + 1) * subplots_per_fig, np.sum(good_decorr_runs))
    
    n_rows = math.ceil(math.sqrt(end_idx - start_idx))
    n_cols = math.ceil((end_idx - start_idx) / n_rows)
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows), dpi=300)
    axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]
    
    for i, session_n in enumerate(range(start_idx, end_idx)):
        for j, mask in enumerate(correlation_matrices):
            mean_values_array = all_masks_matrix[j, good_decorr_runs][session_n]
            axes[i].plot(np.arange(0, len(mean_values_array)*n_iter, n_iter), mean_values_array, 'o-', label=correlation_names[j])
        
        axes[i].set_title(f'LSTM Run {filtered_indices[session_n]+1}')
        axes[i].set_ylim(0, 1)
        axes[i].set_xlabel('Epoch')
        axes[i].set_ylabel('Mean Correlation')
        axes[i].legend()
    
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.suptitle(f'LSTM Decorrelation Analysis (Runs {start_idx+1}-{end_idx} out of {np.sum(good_decorr_runs)} filtered runs)', fontsize=16)
    plt.subplots_adjust(top=0.95)
    plt.savefig(f'LSTM_decorrelation_analysis_{fig_num+1}_{today}.pdf', format='pdf', dpi=300)
    plt.show()

print("LSTM Decorrelation analysis plots completed.")
print(f"Total figures generated: {num_figures}")
print("="*40)

# Plot heatmaps for all masks (filtered runs only)
for m in range(len(correlation_matrices)):
    plt.figure(figsize=(10, 8))
    sns.heatmap(all_masks_matrix[m, good_decorr_runs])
    plt.title(f'LSTM Mask {m+1} Heatmap: {correlation_names[m]}')
    plt.xlabel('Epoch')
    plt.ylabel('Run')
    plt.savefig(f'LSTM_mask_{m+1}_heatmap_{today}.pdf', format='pdf', dpi=300)
    plt.show()

print("Mask heatmaps plotted for filtered LSTM runs.")
print("="*40)

# Analyze crossing points (filtered runs only)
cross_thresh = 0.4
run_plot = np.array([True] * np.sum(good_decorr_runs))
where_cross = np.zeros((np.sum(good_decorr_runs), len(correlation_matrices)))

for m in range(len(correlation_matrices)):
    for run in range(np.sum(good_decorr_runs)):
        cross_points = np.where(all_masks_matrix[m, good_decorr_runs][run] < cross_thresh)[0]
        if len(cross_points) > 0:
            where_cross[run, m] = cross_points[0]
        else:
            where_cross[run, m] = all_masks_matrix.shape[2]
            run_plot[run] = False

where_cross = where_cross[run_plot]

plt.figure(figsize=(12, 6))
x_plot = np.repeat(np.array([0,1,2])[:,np.newaxis], where_cross.shape[0], axis=1) + np.random.normal(0,0.05,(3,where_cross.shape[0]))
plt.barh([0,1,2], [np.mean(where_cross[:,0]), np.mean(where_cross[:,1]), np.mean(where_cross[:,2])], color='lightblue')
plt.plot(np.vstack((where_cross[:,0], where_cross[:,1], where_cross[:,2])), x_plot, color='gray')
plt.plot(np.vstack((where_cross[:,0], where_cross[:,1], where_cross[:,2])), x_plot, 'o', color='black')
plt.yticks([0,1,2], correlation_names)
plt.title('LSTM Crossing Points Analysis (Filtered Runs)')
plt.xlabel('Epoch')
plt.savefig(f'LSTM_crossing_points_{today}.pdf', format='pdf', dpi=300)
plt.show()

print("LSTM Crossing points analysis completed and plotted for filtered runs.")
print(f"Mean crossing epoch for {correlation_names[0]}: {np.mean(where_cross[:,0]):.2f}")
print(f"Mean crossing epoch for {correlation_names[1]}: {np.mean(where_cross[:,1]):.2f}")
print(f"Mean crossing epoch for {correlation_names[2]}: {np.mean(where_cross[:,2]):.2f}")
print("="*40)

print("LSTM Analysis completed.")
print(f"Summary:")
print(f"- Total LSTM simulations: {corr_curve.shape[0]}")
print(f"- LSTM runs with loss < {loss_thresh}: {good_runs}")
print(f"- LSTM runs passing both loss and decorrelation thresholds: {np.sum(good_decorr_runs)}")
print(f"- Final mean loss (all LSTM runs): {np.mean(loss_all[:,-1]):.4f}")
print(f"- Final mean loss (filtered LSTM runs): {np.mean(loss_all[filtered_indices, -1]):.4f}")
print(f"- Final mean accuracy (all LSTM runs): {np.mean(accuracy_curve_all_test[:,-1]):.4f}")
print(f"- Final mean accuracy (filtered LSTM runs): {np.mean(accuracy_curve_all_test[filtered_indices, -1]):.4f}")
print(f"- Mean last-step correlation (filtered LSTM runs): {np.mean(corr_avg_last_session):.4f}")
print("The analysis suggests that the LSTM model with Dropout regularization on activations is learning to decorrelate representations over time, with different regions showing distinct patterns of decorrelation.")
print(f"Decorrelation is particularly strong in LSTM runs that pass both the loss threshold of {loss_thresh} and the decorrelation threshold of {decorr_thresh}.")
print("The Dropout regularization on activations may have influenced the model's ability to learn sparse and decorrelated representations.")
print("Further analysis might be needed to compare these results with the previous model without Dropout regularization on activations.")
# Out:
# Analysis of GPU LSTM Model Results with L1 Regularization on Activations
# ========================================
# Loading LSTM data from files with timestamp: 2024-09-05-16-50
# Data loaded successfully.
# Total number of simulations: 8
# Number of epochs: 300
# Correlation matrix size: 46x46
# ========================================
# Basic Statistics:
# Final mean loss: 0.0363
# Final mean accuracy: 1.0000
# Number of runs with good convergence (loss < 10): 8
# Percentage of good runs: 100.00%
# ========================================
# Average accuracy curve plotted for good runs.
# Final average accuracy for good runs: 100.0000%
# ========================================
# Overall mean of the last frame covariance matrix: 0.3317
# SEM: 0.0295
# Individual means for each run:
# [0.35271576 0.35549238 0.44852973 0.27786672 0.27768864 0.46456142
#  0.24547197 0.23109883]
# ========================================
# Correlation matrices plotted for selected epochs.
# ========================================
# Last time step mean correlation statistics:
# Mean: 0.3317
# Median: 0.3153
# Min: 0.2311
# Max: 0.4646
# ========================================
# Mean correlation matrix plotted.
# ========================================
# Number of LSTM runs passing both loss and decorrelation thresholds: 8
# Percentage of good LSTM runs passing decorrelation threshold: 100.00%
# ========================================
# LSTM Decorrelation analysis plots completed.
# Total figures generated: 1
# ========================================
# Mask heatmaps plotted for filtered LSTM runs.
# ========================================
# /groups/spruston/home/sunw2/anaconda3/envs/vr2pai/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /groups/spruston/home/sunw2/anaconda3/envs/vr2pai/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# LSTM Crossing points analysis completed and plotted for filtered runs.
# Mean crossing epoch for Off-diagonal: nan
# Mean crossing epoch for Pre-R2: nan
# Mean crossing epoch for Pre-R1: nan
# ========================================
# LSTM Analysis completed.
# Summary:
# - Total LSTM simulations: 8
# - LSTM runs with loss < 10: 8
# - LSTM runs passing both loss and decorrelation thresholds: 8
# - Final mean loss (all LSTM runs): 0.0363
# - Final mean loss (filtered LSTM runs): 0.0363
# - Final mean accuracy (all LSTM runs): 1.0000
# - Final mean accuracy (filtered LSTM runs): 1.0000
# - Mean last-step correlation (filtered LSTM runs): 0.3317
# The analysis suggests that the LSTM model with L1 regularization on activations is learning to decorrelate representations over time, with different regions showing distinct patterns of decorrelation.
# Decorrelation is particularly strong in LSTM runs that pass both the loss threshold of 10 and the decorrelation threshold of 10.3.
# The L1 regularization on activations may have influenced the model's ability to learn sparse and decorrelated representations.
# Further analysis might be needed to compare these results with the previous model without L1 regularization on activations.
