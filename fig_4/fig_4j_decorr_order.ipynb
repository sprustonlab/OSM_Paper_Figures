# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
import numpy as np
from scipy.stats import ttest_rel

# Data
models = ['Vanilla RNN (Polynomial)', 'Vanilla RNN (Softmax)', 'Hebbian-RNN', 'CSCG', 'Animal']
regions = ['Pre-R2', 'Pre-R1', 'Off diagonal']  # Reversed order of regions

# Existing data (now we'll reverse the order of rows in each data array)
Animal_data = np.array([[0.41641642, 0.50550551, 0.33433433, 0.27727728, 0.42742743,
                         0.13613614, 0.39139139, 0.48048048, 0.93493493, 0.50550551,
                         0.0980981 ],
                        [0.76976977, 0.80980981, 0.87487487, 0.28528529, 0.97797798,
                         0.07707708, 0.58258258, 0.83383383, 0.81681682, 0.31431431,
                         0.14714715],
                        [0.        , 0.        , 0.01901902, 0.        , 0.00500501,
                         0.        , 0.        , 0.1001001 , 0.        , 0.        ,
                         0.        ]])

CSCG_data = np.array([[0.36734694, 0.24489796, 0.46938776, 0.2244898 , 0.6122449 ,
                       0.18367347, 0.24489796, 0.30612245, 0.20408163, 0.26530612,
                       0.28571429, 0.46938776, 0.36734694, 0.16326531, 0.93877551,
                       0.14285714, 0.63265306, 0.24489796],
                      [0.95918367, 1.        , 0.95918367, 0.95918367, 0.89795918,
                       0.95918367, 0.95918367, 0.95918367, 0.95918367, 0.97959184,
                       0.97959184, 0.95918367, 0.97959184, 1.        , 0.81632653,
                       1.        , 0.93877551, 0.95918367],
                      [0.08163265, 0.04081633, 0.06122449, 0.06122449, 0.12244898,
                       0.04081633, 0.06122449, 0.08163265, 0.04081633, 0.04081633,
                       0.06122449, 0.06122449, 0.06122449, 0.04081633, 0.08163265,
                       0.04081633, 0.08163265, 0.06122449]])

Hebbian_RNN_data = np.array([[0.75510204, 0.08163265, 0.87755102, 0.51020408, 0.81632653,
                              0.08163265, 0.75510204, 0.67346939],
                             [0.02040816, 0.        , 0.02040816, 0.04081633, 0.        ,
                              0.02040816, 0.02040816, 0.06122449],
                             [0.        , 0.        , 0.02040816, 0.        , 0.        ,
                              0.02040816, 0.        , 0.        ]])


Vanilla_RNN_Softmax_data = np.array([[0.92      , 0.92857143, 0.75      , 0.84615385, 0.69230769,
        0.85714286, 0.85714286, 0.89473684, 0.73333333, 0.8       ,
        0.95238095, 0.83333333, 0.88888889, 0.77272727, 0.625     ],
       [0.28      , 0.75      , 0.83333333, 0.84615385, 0.84615385,
        0.57142857, 0.85714286, 0.36842105, 0.86666667, 0.7       ,
        0.19047619, 0.58333333, 0.88888889, 0.90909091, 0.875     ],
       [0.16      , 0.14285714, 0.33333333, 0.30769231, 0.30769231,
        0.28571429, 0.28571429, 0.21052632, 0.26666667, 0.4       ,
        0.0952381 , 0.25      , 0.22222222, 0.18181818, 0.25      ]])
Vanilla_RNN_Polynomial_data = np.array([[0.86666667, 0.66666667, 0.71428571, 0.66666667, 0.8       ,
        0.75      , 0.57142857, 0.5       , 0.71428571, 0.625     ,
        0.5       , 0.57142857, 0.45454545, 0.71428571, 0.81818182,
        0.625     , 0.66666667, 0.9047619 , 0.75      , 0.57142857,
        0.75      , 0.57142857, 0.875     , 0.77777778, 0.75      ,
        0.71428571, 0.75      , 0.625     , 0.71428571, 0.86666667,
        0.5       , 0.75      , 0.75      , 0.8       , 0.7       ,
        0.77777778, 0.75      , 0.71428571, 0.625     ],
       [0.26666667, 0.66666667, 0.57142857, 0.66666667, 0.4       ,
        0.625     , 0.71428571, 0.75      , 0.57142857, 0.75      ,
        0.66666667, 0.71428571, 0.81818182, 0.71428571, 0.45454545,
        0.75      , 0.5       , 0.19047619, 0.625     , 0.71428571,
        0.5       , 0.71428571, 0.3125    , 0.55555556, 0.5       ,
        0.57142857, 0.5       , 0.75      , 0.42857143, 0.26666667,
        0.75      , 0.625     , 0.625     , 0.5       , 0.8       ,
        0.66666667, 0.625     , 0.57142857, 0.75      ],
       [0.13333333, 0.33333333, 0.14285714, 0.16666667, 0.2       ,
        0.25      , 0.28571429, 0.125     , 0.28571429, 0.25      ,
        0.33333333, 0.28571429, 0.09090909, 0.28571429, 0.18181818,
        0.25      , 0.16666667, 0.04761905, 0.25      , 0.28571429,
        0.25      , 0.28571429, 0.125     , 0.22222222, 0.25      ,
        0.28571429, 0.25      , 0.125     , 0.28571429, 0.13333333,
        0.25      , 0.25      , 0.25      , 0.2       , 0.2       ,
        0.22222222, 0.125     , 0.28571429, 0.25      ]])

data = [
    np.mean(Vanilla_RNN_Polynomial_data, axis=1),
    np.mean(Vanilla_RNN_Softmax_data, axis=1),
    np.mean(Hebbian_RNN_data, axis=1),
    np.mean(CSCG_data, axis=1),
    np.mean(Animal_data, axis=1)
]

errors = [
    np.std(Vanilla_RNN_Polynomial_data, axis=1) / np.sqrt(Vanilla_RNN_Polynomial_data.shape[1]),
    np.std(Vanilla_RNN_Softmax_data, axis=1) / np.sqrt(Vanilla_RNN_Softmax_data.shape[1]),
    np.std(Hebbian_RNN_data, axis=1) / np.sqrt(Hebbian_RNN_data.shape[1]),
    np.std(CSCG_data, axis=1) / np.sqrt(CSCG_data.shape[1]),
    np.std(Animal_data, axis=1) / np.sqrt(Animal_data.shape[1])
]

# Set bar width
bar_width = 0.25

# Set figure size
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 10), gridspec_kw={'width_ratios': [4, 1]})

# Generate y-positions for the models
y_pos = np.arange(len(models))

# Set colors for each region (reversed order)
colors = ['#C06C84', '#F67280', '#6C5B7B']


# Plot bars for each region within each model
for i, (region, color) in enumerate(zip(regions, colors)):
    ax1.barh(y_pos + i * bar_width, [d[i] for d in data], height=bar_width, align='center', color=color, edgecolor='black', linewidth=1.5)
    ax1.errorbar([d[i] for d in data], y_pos + i * bar_width, xerr=[e[i] for e in errors], fmt='none', ecolor='black', capsize=6, linewidth=1.5)

# Plot data for each region within each model and connect the dots across regions for each model
model_y_positions = {}
for j, model_data in enumerate([Vanilla_RNN_Polynomial_data, Vanilla_RNN_Softmax_data, Hebbian_RNN_data, CSCG_data, Animal_data]):
    for i, (region, color) in enumerate(zip(regions, colors)):
        y_vals = np.random.normal(y_pos[j] + i * bar_width, 0.02, size=model_data.shape[1])
        ax1.scatter(model_data[i], y_vals, color='black', alpha=0.8, s=30, zorder=3)
        
        if i == 0:
            model_y_positions[j] = y_vals
        else:
            for k in range(min(model_data.shape[1], model_y_positions[j].shape[0])):
                ax1.plot([model_data[i-1][k], model_data[i][k]], [model_y_positions[j][k], y_vals[k]], color='grey', linestyle='-', linewidth=1, zorder=2)
            
            model_y_positions[j] = y_vals

# Calculate p-values for each pair of regions within each model using paired t-tests
for model, model_data in zip(models, [Vanilla_RNN_Polynomial_data, Vanilla_RNN_Softmax_data, Hebbian_RNN_data, CSCG_data, Animal_data]):
    print(f"P-values for {model}:")
    for i in range(len(regions)):
        for j in range(i+1, len(regions)):
            _, p_value = ttest_rel(model_data[i], model_data[j])
            print(f"{regions[i]} vs {regions[j]}: p={p_value:.8f}")
    print()

# Set y-tick labels
ax1.set_yticks(y_pos + bar_width)
ax1.set_yticklabels(models, fontsize=12)

# Set the x-axis label and increase font size
ax1.set_xlabel('Normalized Time to Cross Threshold', fontsize=14)

# Set title
ax1.set_title('Region Comparison', fontsize=16)

# Increase font size of tick labels
ax1.tick_params(axis='both', labelsize=12)

# Remove top and right spines
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# Create a separate plot for the legend
handles = [plt.Rectangle((0, 0), 1, 1, color=color) for color in colors]
labels = regions
ax2.legend(handles, labels, fontsize=12, loc='center')
ax2.axis('off')

# Adjust layout and display the plot
fig.tight_layout()
plt.savefig('figure_4j.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# P-values for Vanilla RNN (Polynomial):
# Pre-R2 vs Pre-R1: p=0.01452386
# Pre-R2 vs Off diagonal: p=0.00000000
# Pre-R1 vs Off diagonal: p=0.00000000
#
# P-values for Vanilla RNN (Softmax):
# Pre-R2 vs Pre-R1: p=0.11715357
# Pre-R2 vs Off diagonal: p=0.00000000
# Pre-R1 vs Off diagonal: p=0.00000103
#
# P-values for Hebbian-RNN:
# Pre-R2 vs Pre-R1: p=0.00180208
# Pre-R2 vs Off diagonal: p=0.00163431
# Pre-R1 vs Off diagonal: p=0.06392413
#
# P-values for CSCG:
# Pre-R2 vs Pre-R1: p=0.00000001
# Pre-R2 vs Off diagonal: p=0.00000561
# Pre-R1 vs Off diagonal: p=0.00000000
#
# P-values for Animal:
# Pre-R2 vs Pre-R1: p=0.04405412
# Pre-R2 vs Off diagonal: p=0.00014037
# Pre-R1 vs Off diagonal: p=0.00011897
